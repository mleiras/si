# %%
import pandas as pd
import numpy as np

# %%
import sys
sys.path.insert(0, "/home/monica/Documents/2_ano/sistemas/si/") 
from src.si.data.dataset import Dataset
from src.si.feature_selection.select_k_best import SelectKBest
from src.si.feature_selection.select_percentile import SelectPercentile
from src.si.feature_selection.variance_threshold import VarianceThreshold
from src.si.statistics.f_classification import f_classification

# %%
from src.si.io_folder.module_csv import read_csv

# %% [markdown]
# # Avaliação Aula 1 (26-09-2022)

# %% [markdown]
# ## Exercício 1: NumPy array Indexing/Slicing

# %% [markdown]
# ##### 1.1 Neste exercício, vamos usar o iris dataset. Carrega o iris.csv usando o método read apropriado para o tipo de ficheiro.

# %%
iris = read_csv('/home/monica/Documents/2_ano/sistemas/si/datasets/iris.csv', sep=',',features=True, label=True)
iris.X.head()
# Out:
# /tmp/ipykernel_24931/2189443197.py:1: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   iris = read_csv('/home/monica/Documents/2_ano/sistemas/si/datasets/iris.csv', sep=',',features=True, label=True)
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %% [markdown]
# ##### 1.2) Seleciona a primeira variável independente e verifica a dimensão do array resultante.

# %%
var1 = iris.X['sepal_length']
var1.shape
# Out:
# (150,)

# %% [markdown]
# ##### 1.3) Seleciona as últimas 5 amostras do iris dataset. Qual a média das últimas 5 amostras para cada variável independente/feature?

# %%
ultimas_amostras = iris.X.tail()
ultimas_amostras.mean(axis=0)
# Out:
# sepal_length    6.32
# sepal_width     2.98
# petal_length    5.18
# petal_width     2.06
# dtype: float64

# %% [markdown]
# ##### 1.4) Seleciona todas as amostras do dataset com valor superior ou igual a 1. Nota que o array resultante deve ter apenas amostras com valores iguais ou superiores a 1 para todas as features.

# %%
iris.X.loc[(iris.X['petal_width'] > 1) & (iris.X['petal_length'] > 1) & (iris.X['sepal_length'] > 1) & (iris.X['sepal_width'] >1)]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 50            7.0          3.2           4.7          1.4
# 51            6.4          3.2           4.5          1.5
# 52            6.9          3.1           4.9          1.5
# 53            5.5          2.3           4.0          1.3
# 54            6.5          2.8           4.6          1.5
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [93 rows x 4 columns]

# %% [markdown]
# ##### 1.5) Seleciona todas as amostras com a classe/label igual a ‘Iris- setosa’. Quantas amostras obténs?

# %%
iris.X[iris.y == 'Iris-setosa']
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 0            5.1          3.5           1.4          0.2
# 1            4.9          3.0           1.4          0.2
# 2            4.7          3.2           1.3          0.2
# 3            4.6          3.1           1.5          0.2
# 4            5.0          3.6           1.4          0.2
# 5            5.4          3.9           1.7          0.4
# 6            4.6          3.4           1.4          0.3
# 7            5.0          3.4           1.5          0.2
# 8            4.4          2.9           1.4          0.2
# 9            4.9          3.1           1.5          0.1
# 10           5.4          3.7           1.5          0.2
# 11           4.8          3.4           1.6          0.2
# 12           4.8          3.0           1.4          0.1
# 13           4.3          3.0           1.1          0.1
# 14           5.8          4.0           1.2          0.2
# 15           5.7          4.4           1.5          0.4
# 16           5.4          3.9           1.3          0.4
# 17           5.1          3.5           1.4          0.3
# 18           5.7          3.8           1.7          0.3
# 19           5.1          3.8           1.5          0.3
# 20           5.4          3.4           1.7          0.2
# 21           5.1          3.7           1.5          0.4
# 22           4.6          3.6           1.0          0.2
# 23           5.1          3.3           1.7          0.5
# 24           4.8          3.4           1.9          0.2
# 25           5.0          3.0           1.6          0.2
# 26           5.0          3.4           1.6          0.4
# 27           5.2          3.5           1.5          0.2
# 28           5.2          3.4           1.4          0.2
# 29           4.7          3.2           1.6          0.2
# 30           4.8          3.1           1.6          0.2
# 31           5.4          3.4           1.5          0.4
# 32           5.2          4.1           1.5          0.1
# 33           5.5          4.2           1.4          0.2
# 34           4.9          3.1           1.5          0.1
# 35           5.0          3.2           1.2          0.2
# 36           5.5          3.5           1.3          0.2
# 37           4.9          3.1           1.5          0.1
# 38           4.4          3.0           1.3          0.2
# 39           5.1          3.4           1.5          0.2
# 40           5.0          3.5           1.3          0.3
# 41           4.5          2.3           1.3          0.3
# 42           4.4          3.2           1.3          0.2
# 43           5.0          3.5           1.6          0.6
# 44           5.1          3.8           1.9          0.4
# 45           4.8          3.0           1.4          0.3
# 46           5.1          3.8           1.6          0.2
# 47           4.6          3.2           1.4          0.2
# 48           5.3          3.7           1.5          0.2
# 49           5.0          3.3           1.4          0.2

# %%
iris.X[iris.y == 'Iris-setosa'].shape
# Out:
# (50, 4)

# %% [markdown]
# ## Exercicio 2

# %% [markdown]
# ##### 2.1) Adiciona um método ao objeto Dataset que remove todas as amostras que contêm pelo menos um valor nulo (NaN). Nota que o objeto resultante não deve conter valores nulos em para nenhuma feature/variável independente. Nota também que deves atualizar o vetor y removendo as entradas associadas às amostras a remover. Deves usar apenas funções no NumPy. Nome do método: dropna

# %%
# Alterado diretamente no objeto Dataset.

# %% [markdown]
# ##### 2.2) Adiciona um método ao objeto Dataset que substitui todas os valores nulos por outro valor (argumento da função/método). Nota que o objeto resultante não deve conter valores nulos em para nenhuma feature/variável independente. Deves usar apenas funções no NumPy. Nome do método: fillna

# %%
# Alterado diretamente no objeto Dataset.

# %% [markdown]
# # Avaliação Aula 2 (03/10/2022)

# %% [markdown]
# ## Exercício 3: Implementar o SelectPercentile

# %% [markdown]
# ##### 3.1) Adiciona o objeto SelectPercentile ao sub-package feature_selection. Deves criar um módulo chamado select_percentile.py para implementar este objeto

# %% [markdown]
# ##### 3.2) A class SelectPercentile tem uma arquitetura semelhante à classe SelectKBest. Considera a estrutura apresentada no diapositivo seguinte.
#
# class SelectPercentile:
#
# Parâmetros:
# - score_func – função de análise da variância (f_classification ou f_regression)
# - percentile – percentil para as features a selecionar
#
# Parâmetros estimados:
#
# - F – o valor de F para cada feature estimado pela score_func
# - p – o valor de p para cada feature estimado pela score_func
#
# Métodos:
# - fit – estima o F e p para cada feature usando a scoring_func; retorna o self  (ele próprio)
# - transform – seleciona as features com valor de F mais alto até ao percentil indicado. Por exemplo, para um dataset com 10 features e um percentil de 50%, o teu transform deve selecionar as 5 features com valor de F mais alto
# - fit_transform – corre o fit e depois o transform

# %% [markdown]
# ##### 3.3) Podes testar a class SelectPercentile num jupyter notebook usando o dataset iris.csv (classificação).

# %%
# dataset = Dataset(X=np.array([[0, 2, 0, 3],
#                                 [0, 1, 4, 3],
#                                 [0, 1, 1, 3]]),
#                     y=np.array([0, 1, 0]),
#                     features=["f1", "f2", "f3", "f4"],
#                     label="y")

selector = SelectKBest(f_classification, 1)
dataset = selector.fit_transform(iris)
print(dataset.features)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), array([2]))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# /home/monica/Documents/2_ano/sistemas/si/scripts/Exercicios.ipynb Cell 28 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/home/monica/Documents/2_ano/sistemas/si/scripts/Exercicios.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> # dataset = Dataset(X=np.array([[0, 2, 0, 3],
#       <a href='vscode-notebook-cell:/home/monica/Documents/2_ano/sistemas/si/scripts/Exercicios.ipynb#X36sZmlsZQ%3D%3D?line=1'>2</a> #                                 [0, 1, 4, 3],
#       <a href='vscode-notebook-cell:/home/monica/Documents/2_ano/sistemas/si/scripts/Exercicios.ipynb#X36sZmlsZQ%3D%3D?line=2'>3</a> #                                 [0, 1, 1, 3]]),
#       <a href='vscode-notebook-cell:/home/monica/Documents/2_ano/sistemas/si/scripts/Exercicios.ipynb#X36sZmlsZQ%3D%3D?line=3'>4</a> #                     y=np.array([0, 1, 0]),
#       <a href='vscode-notebook-cell:/home/monica/Documents/2_ano/sistemas/si/scripts/Exercicios.ipynb#X36sZmlsZQ%3D%3D?line=4'>5</a> #                     features=["f1", "f2", "f3", "f4"],
#       <a href='vscode-notebook-cell:/home/monica/Documents/2_ano/sistemas/si/scripts/Exercicios.ipynb#X36sZmlsZQ%3D%3D?line=5'>6</a> #                     label="y")
#       <a href='vscode-notebook-cell:/home/monica/Documents/2_ano/sistemas/si/scripts/Exercicios.ipynb#X36sZmlsZQ%3D%3D?line=7'>8</a> selector = SelectKBest(f_classification, 1)
# ----> <a href='vscode-notebook-cell:/home/monica/Documents/2_ano/sistemas/si/scripts/Exercicios.ipynb#X36sZmlsZQ%3D%3D?line=8'>9</a> dataset = selector.fit_transform(iris)
#      <a href='vscode-notebook-cell:/home/monica/Documents/2_ano/sistemas/si/scripts/Exercicios.ipynb#X36sZmlsZQ%3D%3D?line=9'>10</a> print(dataset.features)
#
# File ~/Documents/2_ano/sistemas/si/src/si/feature_selection/select_k_best.py:33, in SelectKBest.fit_transform(self, dataset)
#      31 def fit_transform(self, dataset):
#      32     self.fit(dataset)
# ---> 33     return self.transform(dataset)
#
# File ~/Documents/2_ano/sistemas/si/src/si/feature_selection/select_k_best.py:28, in SelectKBest.transform(self, dataset)
#      26 idx = np.argsort(self.F)[-self.k:]
#      27 features= np.array(dataset.features)[idx] # selecionar as features com base nos idx
# ---> 28 return Dataset(dataset.X[:,idx], y=dataset.y, features=list(features), label=dataset.label)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3628, in Index.get_loc(self, key, method, tolerance)
#    3623         raise KeyError(key) from err
#    3624     except TypeError:
#    3625         # If we have a listlike key, _check_indexing_error will raise
#    3626         #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627         #  the TypeError.
# -> 3628         self._check_indexing_error(key)
#    3629         raise
#    3631 # GH#42269
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5637, in Index._check_indexing_error(self, key)
#    5633 def _check_indexing_error(self, key):
#    5634     if not is_scalar(key):
#    5635         # if key is not a scalar, directly raise an error (the code below
#    5636         # would convert to numpy arrays and raise later any way) - GH29926
# -> 5637         raise InvalidIndexError(key)
#
# InvalidIndexError: (slice(None, None, None), array([2]))

# %%
selector = SelectPercentile(f_classification, 25)
dataset = selector.fit_transform(iris)
# print(iris.features)
print(dataset.features)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///home/monica/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///home/monica/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///home/monica/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), array([1, 0, 3, 2]))' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# /home/monica/Documents/2_ano/sistemas/si/scripts/Exercicios.ipynb Cell 27' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/monica/Documents/2_ano/sistemas/si/scripts/Exercicios.ipynb#ch0000026?line=0'>1</a> selector = SelectPercentile(f_classification, 25)
# ----> <a href='vscode-notebook-cell:/home/monica/Documents/2_ano/sistemas/si/scripts/Exercicios.ipynb#ch0000026?line=1'>2</a> dataset = selector.fit_transform(iris)
#       <a href='vscode-notebook-cell:/home/monica/Documents/2_ano/sistemas/si/scripts/Exercicios.ipynb#ch0000026?line=2'>3</a> # print(iris.features)
#       <a href='vscode-notebook-cell:/home/monica/Documents/2_ano/sistemas/si/scripts/Exercicios.ipynb#ch0000026?line=3'>4</a> print(dataset.features)
#
# File ~/Documents/2_ano/sistemas/si/src/si/feature_selection/select_percentile.py:34, in SelectPercentile.fit_transform(self, dataset)
#      <a href='file:///home/monica/Documents/2_ano/sistemas/si/src/si/feature_selection/select_percentile.py?line=31'>32</a> def fit_transform(self, dataset):
#      <a href='file:///home/monica/Documents/2_ano/sistemas/si/src/si/feature_selection/select_percentile.py?line=32'>33</a>     self.fit(dataset)
# ---> <a href='file:///home/monica/Documents/2_ano/sistemas/si/src/si/feature_selection/select_percentile.py?line=33'>34</a>     return self.transform(dataset)
#
# File ~/Documents/2_ano/sistemas/si/src/si/feature_selection/select_percentile.py:29, in SelectPercentile.transform(self, dataset)
#      <a href='file:///home/monica/Documents/2_ano/sistemas/si/src/si/feature_selection/select_percentile.py?line=26'>27</a> idx = np.argsort(self.F)[-mask:]
#      <a href='file:///home/monica/Documents/2_ano/sistemas/si/src/si/feature_selection/select_percentile.py?line=27'>28</a> features= np.array(dataset.features)[idx] # selecionar as features com base nos idx
# ---> <a href='file:///home/monica/Documents/2_ano/sistemas/si/src/si/feature_selection/select_percentile.py?line=28'>29</a> return Dataset(dataset.X[:,idx], y=dataset.y, features=list(features), label=dataset.label)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    <a href='file:///home/monica/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3502'>3503</a> if self.columns.nlevels > 1:
#    <a href='file:///home/monica/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3503'>3504</a>     return self._getitem_multilevel(key)
# -> <a href='file:///home/monica/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3504'>3505</a> indexer = self.columns.get_loc(key)
#    <a href='file:///home/monica/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3505'>3506</a> if is_integer(indexer):
#    <a href='file:///home/monica/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py?line=3506'>3507</a>     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3628, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///home/monica/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3622'>3623</a>         raise KeyError(key) from err
#    <a href='file:///home/monica/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3623'>3624</a>     except TypeError:
#    <a href='file:///home/monica/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3624'>3625</a>         # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///home/monica/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3625'>3626</a>         #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///home/monica/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3626'>3627</a>         #  the TypeError.
# -> <a href='file:///home/monica/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a>         self._check_indexing_error(key)
#    <a href='file:///home/monica/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3628'>3629</a>         raise
#    <a href='file:///home/monica/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3630'>3631</a> # GH#42269
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5637, in Index._check_indexing_error(self, key)
#    <a href='file:///home/monica/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=5632'>5633</a> def _check_indexing_error(self, key):
#    <a href='file:///home/monica/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=5633'>5634</a>     if not is_scalar(key):
#    <a href='file:///home/monica/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=5634'>5635</a>         # if key is not a scalar, directly raise an error (the code below
#    <a href='file:///home/monica/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=5635'>5636</a>         # would convert to numpy arrays and raise later any way) - GH29926
# -> <a href='file:///home/monica/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=5636'>5637</a>         raise InvalidIndexError(key)
#
# InvalidIndexError: (slice(None, None, None), array([1, 0, 3, 2]))
